# %% [markdown]
# ### Example
# d1 = {'gene': 'eml1', 'idnumbers': [5,6,7,9,10,11,12,13], 'letters': ['wt','B','C','D','E','F','G','H']}
#
# d2 = {'gene': 'cpne3', 'idnumbers': [1,2,3,5], 'letters': ['wt','B','C','D','E','F','G','H']}
#
# metad = [d1,d2]

# %%
d1 = {'gene': 'cpne3', 'idnumbers': [4,6,7,8], 'letters': ['wt','B','C','D','E','F','G','H']}
d1e = {'gene': 'EMPTY', 'idnumbers': [0,0,0,0], 'letters': ['']}
d1b = {'gene': 'cpne3', 'idnumbers': [8,7,6,4], 'letters': ['I']}
d2 = {'gene': 'eml1', 'idnumbers': [8], 'letters': ['wt','B','C','D','E','F','G','H']}
d2e = {'gene': 'EMPTY', 'idnumbers': [0,0,0,0], 'letters': ['']}
d2b = {'gene': 'eml1', 'idnumbers': [8], 'letters': ['I','J','K','L']}
d3 = {'gene': 'tjp2a', 'idnumbers': [6], 'letters': ['wt','B','C','D','E','F','G','H']}
d3e = {'gene': 'EMPTY', 'idnumbers': [0,0,0,0], 'letters': ['']}
d3b = {'gene': 'tjp2a', 'idnumbers': [6], 'letters': ['I','J','K','L']}
d4 = {'gene': 'tjp2b', 'idnumbers': [6], 'letters': ['wt','B','C','D','E','F','G','H']}
metad = [d1,d1e,d1b,d2,d2e,d2b,d3,d3e,d3b,d4]

# %%
for i in range(len(metad)):
    gname = (metad[i]['gene'])
    for j in range(len(metad[i]['idnumbers'])):
        gidn = gname + '-' + str(metad[i]['idnumbers'][j])
        for k in range(len(metad[i]['letters'])):
            print (gidn + '-' + metad[i]['letters'][k])

# %%
d1a = {'gene': 'cadm1a', 'idnumbers': [10,11,12], 'letters': ['wt','B','C','D','E','F','G','H']}
d1b = {'gene': 'cadm1b', 'idnumbers': [10,11,12], 'letters': ['wt','B','C','D','E','F','G','H']}
d2 = {'gene': 'cpne3', 'idnumbers': [9,10], 'letters': ['wt','B','C','D','E','F','G','H']}
d3a = {'gene': 'tjp2a', 'idnumbers': [7,9], 'letters': ['wt','B','C','D','E','F','G','H']}
d3b = {'gene': 'tjp2b', 'idnumbers': [7,9], 'letters': ['wt','B','C','D','E','F','G','H']}
d4s = {'gene': 'nrxn3aS', 'idnumbers': [2,3,4], 'letters': ['wt','B','C','D','E','F','G','H']}
d4l = {'gene': 'nrxn3aL', 'idnumbers': [2,3,4], 'letters': ['wt','B','C','D','E','F','G','H']}
d5s = {'gene': 'nrxn3bS', 'idnumbers': [2,3,4], 'letters': ['wt','B','C','D','E','F','G','H']}
d5l = {'gene': 'nrxn3bL', 'idnumbers': [2,3,4], 'letters': ['wt','B','C','D','E','F','G','H']}

# %%
metad = [d1a,d1b,d2,d3a,d3b]
for i in range(len(metad)):
    gname = (metad[i]['gene'])
    for j in range(len(metad[i]['idnumbers'])):
        gidn = gname + '-' + str(metad[i]['idnumbers'][j])
        for k in range(len(metad[i]['letters'])):
            print (gidn + '-' + metad[i]['letters'][k])
# Out:
# cadm1a-10-wt
# cadm1a-10-B
# cadm1a-10-C
# cadm1a-10-D
# cadm1a-10-E
# cadm1a-10-F
# cadm1a-10-G
# cadm1a-10-H
# cadm1a-11-wt
# cadm1a-11-B
# cadm1a-11-C
# cadm1a-11-D
# cadm1a-11-E
# cadm1a-11-F
# cadm1a-11-G
# cadm1a-11-H
# cadm1a-12-wt
# cadm1a-12-B
# cadm1a-12-C
# cadm1a-12-D
# cadm1a-12-E
# cadm1a-12-F
# cadm1a-12-G
# cadm1a-12-H
# cadm1b-10-wt
# cadm1b-10-B
# cadm1b-10-C
# cadm1b-10-D
# cadm1b-10-E
# cadm1b-10-F
# cadm1b-10-G
# cadm1b-10-H
# cadm1b-11-wt
# cadm1b-11-B
# cadm1b-11-C
# cadm1b-11-D
# cadm1b-11-E
# cadm1b-11-F
# cadm1b-11-G
# cadm1b-11-H
# cadm1b-12-wt
# cadm1b-12-B
# cadm1b-12-C
# cadm1b-12-D
# cadm1b-12-E
# cadm1b-12-F
# cadm1b-12-G
# cadm1b-12-H
# cpne3-9-wt
# cpne3-9-B
# cpne3-9-C
# cpne3-9-D
# cpne3-9-E
# cpne3-9-F
# cpne3-9-G
# cpne3-9-H
# cpne3-10-wt
# cpne3-10-B
# cpne3-10-C
# cpne3-10-D
# cpne3-10-E
# cpne3-10-F
# cpne3-10-G
# cpne3-10-H
# tjp2a-7-wt
# tjp2a-7-B
# tjp2a-7-C
# tjp2a-7-D
# tjp2a-7-E
# tjp2a-7-F
# tjp2a-7-G
# tjp2a-7-H
# tjp2a-9-wt
# tjp2a-9-B
# tjp2a-9-C
# tjp2a-9-D
# tjp2a-9-E
# tjp2a-9-F
# tjp2a-9-G
# tjp2a-9-H
# tjp2b-7-wt
# tjp2b-7-B
# tjp2b-7-C
# tjp2b-7-D
# tjp2b-7-E
# tjp2b-7-F
# tjp2b-7-G
# tjp2b-7-H
# tjp2b-9-wt
# tjp2b-9-B
# tjp2b-9-C
# tjp2b-9-D
# tjp2b-9-E
# tjp2b-9-F
# tjp2b-9-G
# tjp2b-9-H

# %%
metad = [d4s,d4l,d5s,d5l]
for i in range(len(metad)):
    gname = (metad[i]['gene'])
    for j in range(len(metad[i]['idnumbers'])):
        gidn = gname + '-' + str(metad[i]['idnumbers'][j])
