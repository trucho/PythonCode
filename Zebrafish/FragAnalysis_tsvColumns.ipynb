# %%
import numpy as np
def printNames(nameDict):
    for i in range(len(nameDict)):
        gname = (nameDict[i]['gene'])
        for j in range(len(nameDict[i]['idnumbers'])):
            gidn = gname + '.' + str(nameDict[i]['idnumbers'][j])
            for k in range(len(nameDict[i]['letters'])):
                print (gidn + '_' + nameDict[i]['letters'][k])

# %% [markdown]
# ### Example
# d1 = {'gene': 'eml1', 'idnumbers': [5,6,7,9,10,11,12,13], 'letters': ['wt','B','C','D','E','F','G','H']}
#
# d2 = {'gene': 'cpne3', 'idnumbers': [1,2,3,5], 'letters': ['wt','B','C','D','E','F','G','H']}
#
# metad = [d1,d2]

# %%
d1 = {'gene': 'nrxn3bL', 'idnumbers': np.arange(9,17), 'letters': ['wt','B','C','D','E','F','G','H']}
d2 = {'gene': 'cadm1a', 'idnumbers': [13,14], 'letters': ['wt','B','C','D','E','F','G','H']}
d3 = {'gene': 'cadm1b', 'idnumbers': [13,14], 'letters': ['wt','B','C','D','E','F','G','H']}
printNames([d1,d2,d3])
# Out:
# nrxn3bL.9_wt
# nrxn3bL.9_B
# nrxn3bL.9_C
# nrxn3bL.9_D
# nrxn3bL.9_E
# nrxn3bL.9_F
# nrxn3bL.9_G
# nrxn3bL.9_H
# nrxn3bL.10_wt
# nrxn3bL.10_B
# nrxn3bL.10_C
# nrxn3bL.10_D
# nrxn3bL.10_E
# nrxn3bL.10_F
# nrxn3bL.10_G
# nrxn3bL.10_H
# nrxn3bL.11_wt
# nrxn3bL.11_B
# nrxn3bL.11_C
# nrxn3bL.11_D
# nrxn3bL.11_E
# nrxn3bL.11_F
# nrxn3bL.11_G
# nrxn3bL.11_H
# nrxn3bL.12_wt
# nrxn3bL.12_B
# nrxn3bL.12_C
# nrxn3bL.12_D
# nrxn3bL.12_E
# nrxn3bL.12_F
# nrxn3bL.12_G
# nrxn3bL.12_H
# nrxn3bL.13_wt
# nrxn3bL.13_B
# nrxn3bL.13_C
# nrxn3bL.13_D
# nrxn3bL.13_E
# nrxn3bL.13_F
# nrxn3bL.13_G
# nrxn3bL.13_H
# nrxn3bL.14_wt
# nrxn3bL.14_B
# nrxn3bL.14_C
# nrxn3bL.14_D
# nrxn3bL.14_E
# nrxn3bL.14_F
# nrxn3bL.14_G
# nrxn3bL.14_H
# nrxn3bL.15_wt
# nrxn3bL.15_B
# nrxn3bL.15_C
# nrxn3bL.15_D
# nrxn3bL.15_E
# nrxn3bL.15_F
# nrxn3bL.15_G
# nrxn3bL.15_H
# nrxn3bL.16_wt
# nrxn3bL.16_B
# nrxn3bL.16_C
# nrxn3bL.16_D
# nrxn3bL.16_E
# nrxn3bL.16_F
# nrxn3bL.16_G
# nrxn3bL.16_H
# cadm1a.13_wt
# cadm1a.13_B
# cadm1a.13_C
# cadm1a.13_D
# cadm1a.13_E
# cadm1a.13_F
# cadm1a.13_G
# cadm1a.13_H
# cadm1a.14_wt
# cadm1a.14_B
# cadm1a.14_C
# cadm1a.14_D
# cadm1a.14_E
# cadm1a.14_F
# cadm1a.14_G
# cadm1a.14_H
# cadm1b.13_wt
# cadm1b.13_B
# cadm1b.13_C
# cadm1b.13_D
# cadm1b.13_E
# cadm1b.13_F
# cadm1b.13_G
# cadm1b.13_H
# cadm1b.14_wt
# cadm1b.14_B
# cadm1b.14_C
# cadm1b.14_D
# cadm1b.14_E
# cadm1b.14_F
# cadm1b.14_G
# cadm1b.14_H

# %%
d4s = {'gene': 'nrxn3aS', 'idnumbers': [6,7,8], 'letters': ['wt','B','C','D','E','F','G','H']}
d4l = {'gene': 'nrxn3aL', 'idnumbers': [6,7,8], 'letters': ['wt','B','C','D','E','F','G','H']}
d5s = {'gene': 'nrxn3bS', 'idnumbers': [6,7,8], 'letters': ['wt','B','C','D','E','F','G','H']}
d5l = {'gene': 'nrxn3bL', 'idnumbers': [6,7,8], 'letters': ['wt','B','C','D','E','F','G','H']}
printNames([d4s,d4l,d5s,d5l])

# %%
d1i = {'gene': 'tjp2a', 'idnumbers': [6,7,8,9,11,12], 'letters': ['wti','Bi','Ci','Di','Ei','Fi','Gi','Hi']}
d1ii = {'gene': 'tjp2a', 'idnumbers': [6,7,8,9,11,12], 'letters': ['wtii','Bii','Cii','Dii','Eii','Fii','Gii','Hii']}
# d2 = {'gene': 'tjp2b', 'idnumbers': [8,11,12], 'letters': ['wt','B','C','D','E','F','G','H']}
# d3 = {'gene': 'cadm1a', 'idnumbers': [10,11,12], 'letters': ['wt','B','C','D','E','F','G','H']}
# d4 = {'gene': 'cpne3', 'idnumbers': [11], 'letters': ['wt','B','C','D','E','F','G','H']}
# d5 = {'gene': 'tjp2a_bis', 'idnumbers': [8,11], 'letters': ['wt','B','C','D','E','F','G','H']}
# metad = [d1,d2,d3,d4,d5]
metad = [d1i,d1ii]
printNames(metad)
# Out:
# tjp2a.6_wti
# tjp2a.6_Bi
# tjp2a.6_Ci
# tjp2a.6_Di
# tjp2a.6_Ei
# tjp2a.6_Fi
# tjp2a.6_Gi
# tjp2a.6_Hi
# tjp2a.7_wti
# tjp2a.7_Bi
# tjp2a.7_Ci
# tjp2a.7_Di
# tjp2a.7_Ei
# tjp2a.7_Fi
# tjp2a.7_Gi
# tjp2a.7_Hi
# tjp2a.8_wti
# tjp2a.8_Bi
# tjp2a.8_Ci
# tjp2a.8_Di
# tjp2a.8_Ei
# tjp2a.8_Fi
# tjp2a.8_Gi
# tjp2a.8_Hi
# tjp2a.9_wti
# tjp2a.9_Bi
# tjp2a.9_Ci
# tjp2a.9_Di
# tjp2a.9_Ei
# tjp2a.9_Fi
# tjp2a.9_Gi
# tjp2a.9_Hi
# tjp2a.11_wti
# tjp2a.11_Bi
# tjp2a.11_Ci
# tjp2a.11_Di
# tjp2a.11_Ei
# tjp2a.11_Fi
# tjp2a.11_Gi
# tjp2a.11_Hi
# tjp2a.12_wti
# tjp2a.12_Bi
# tjp2a.12_Ci
# tjp2a.12_Di
# tjp2a.12_Ei
# tjp2a.12_Fi
# tjp2a.12_Gi
# tjp2a.12_Hi
# tjp2a.6_wtii
# tjp2a.6_Bii
# tjp2a.6_Cii
# tjp2a.6_Dii
# tjp2a.6_Eii
# tjp2a.6_Fii
# tjp2a.6_Gii
# tjp2a.6_Hii
# tjp2a.7_wtii
# tjp2a.7_Bii
# tjp2a.7_Cii
# tjp2a.7_Dii
# tjp2a.7_Eii
# tjp2a.7_Fii
# tjp2a.7_Gii
# tjp2a.7_Hii
# tjp2a.8_wtii
# tjp2a.8_Bii
# tjp2a.8_Cii
# tjp2a.8_Dii
# tjp2a.8_Eii
# tjp2a.8_Fii
# tjp2a.8_Gii
# tjp2a.8_Hii
# tjp2a.9_wtii
# tjp2a.9_Bii
# tjp2a.9_Cii
# tjp2a.9_Dii
# tjp2a.9_Eii
# tjp2a.9_Fii
# tjp2a.9_Gii
# tjp2a.9_Hii
# tjp2a.11_wtii
# tjp2a.11_Bii
# tjp2a.11_Cii
# tjp2a.11_Dii
# tjp2a.11_Eii
# tjp2a.11_Fii
# tjp2a.11_Gii
# tjp2a.11_Hii
# tjp2a.12_wtii
# tjp2a.12_Bii
# tjp2a.12_Cii
# tjp2a.12_Dii
# tjp2a.12_Eii
# tjp2a.12_Fii
# tjp2a.12_Gii
# tjp2a.12_Hii
