# %%
import numpy as np
def printNames(nameDict):
    for i in range(len(nameDict)):
        gname = (nameDict[i]['gene'])
        for j in range(len(nameDict[i]['idnumbers'])):
            gidn = gname + '.' + str(nameDict[i]['idnumbers'][j])
            for k in range(len(nameDict[i]['letters'])):
                print (gidn + nameDict[i]['letters'][k])

# %% [markdown]
# ### Example
# d1 = {'gene': 'eml1', 'idnumbers': [5,6,7,9,10,11,12,13], 'letters': ['wt','B','C','D','E','F','G','H']}
#
# d2 = {'gene': 'cpne3', 'idnumbers': [1,2,3,5], 'letters': ['wt','B','C','D','E','F','G','H']}
#
# metad = [d1,d2]

# %%
d1 = {'gene': 'tjp2a', 'idnumbers': [14], 'letters': ['wt','B','C','D','E','F','G','H']}
d2 = {'gene': 'tjp2b', 'idnumbers': [14], 'letters': ['wt','B','C','D','E','F','G','H']}
d3 = {'gene': 'nrxn3bL', 'idnumbers': [17], 'letters': ['wt','B','C','D','E','F','G','H']}
d4 = {'gene': 'nrxn3bS', 'idnumbers': [17], 'letters': ['wt','B','C','D','E','F','G','H']}
d5 = {'gene': 'cadm1a', 'idnumbers': [16,17], 'letters': ['wt','B','C','D','E','F','G','H']}
d6 = {'gene': 'cadm1b', 'idnumbers': [16,17], 'letters': ['wt','B','C','D','E','F','G','H']}
printNames([d1,d2,d3,d4,d5,d6])
# Out:
# tjp2a.14_wt
# tjp2a.14_B
# tjp2a.14_C
# tjp2a.14_D
# tjp2a.14_E
# tjp2a.14_F
# tjp2a.14_G
# tjp2a.14_H
# tjp2b.14_wt
# tjp2b.14_B
# tjp2b.14_C
# tjp2b.14_D
# tjp2b.14_E
# tjp2b.14_F
# tjp2b.14_G
# tjp2b.14_H
# nrxn3bL.17_wt
# nrxn3bL.17_B
# nrxn3bL.17_C
# nrxn3bL.17_D
# nrxn3bL.17_E
# nrxn3bL.17_F
# nrxn3bL.17_G
# nrxn3bL.17_H
# nrxn3bS.17_wt
# nrxn3bS.17_B
# nrxn3bS.17_C
# nrxn3bS.17_D
# nrxn3bS.17_E
# nrxn3bS.17_F
# nrxn3bS.17_G
# nrxn3bS.17_H
# cadm1a.16_wt
# cadm1a.16_B
# cadm1a.16_C
# cadm1a.16_D
# cadm1a.16_E
# cadm1a.16_F
# cadm1a.16_G
# cadm1a.16_H
# cadm1a.17_wt
# cadm1a.17_B
# cadm1a.17_C
# cadm1a.17_D
# cadm1a.17_E
# cadm1a.17_F
# cadm1a.17_G
# cadm1a.17_H
# cadm1b.16_wt
# cadm1b.16_B
# cadm1b.16_C
# cadm1b.16_D
# cadm1b.16_E
# cadm1b.16_F
# cadm1b.16_G
# cadm1b.16_H
# cadm1b.17_wt
# cadm1b.17_B
# cadm1b.17_C
# cadm1b.17_D
# cadm1b.17_E
# cadm1b.17_F
# cadm1b.17_G
# cadm1b.17_H

# %%
d1a = {'gene': 'tjp2a', 'idnumbers': [15], 'letters': ['wt','B','C','D','E','F','G','H']}
d1b = {'gene': 'tjp2a', 'idnumbers': [15], 'letters': ['I','J','K','L','M','N','O','P']}
d1c = {'gene': 'tjp2a', 'idnumbers': [17], 'letters': ['wt','B','C']}
d1d = {'gene': 'tjp2a', 'idnumbers': [18], 'letters': ['I','J','K','L','M']}
d1e = {'gene': 'tjp2a', 'idnumbers': [18], 'letters': ['wt','B','C','D','E','F','G','H']}

d2a = {'gene': 'tjp2b', 'idnumbers': [15], 'letters': ['wt','B','C','D','E','F','G','H']}
d2b = {'gene': 'tjp2b', 'idnumbers': [15], 'letters': ['I','J','K','L','M','N','O','P']}
d2c = {'gene': 'tjp2b', 'idnumbers': [17], 'letters': ['wt','B','C']}
d2d = {'gene': 'tjp2b', 'idnumbers': [18], 'letters': ['I','J','K','L','M']}
d2e = {'gene': 'tjp2b', 'idnumbers': [18], 'letters': ['wt','B','C','D','E','F','G','H']}

d3a = {'gene': 'nrxn3aL', 'idnumbers': [17], 'letters': ['wt','B','C','D','E','F','G','H']}
d3b = {'gene': 'nrxn3aL', 'idnumbers': [17], 'letters': ['I','J','K','L','M','N','O','P']}
d4a = {'gene': 'nrxn3bS', 'idnumbers': [17], 'letters': ['wt','B','C','D','E','F','G','H']}
d4b = {'gene': 'nrxn3bS', 'idnumbers': [17], 'letters': ['I','J','K','L','M','N','O','P']}

printNames([d1a,d1b,d1c,d1d,d1e,d2a,d2b,d2c,d2d,d2e,d3a,d3b,d4a,d4b])
# Out:
# tjp2a.15wt
# tjp2a.15B
# tjp2a.15C
# tjp2a.15D
# tjp2a.15E
# tjp2a.15F
# tjp2a.15G
# tjp2a.15H
# tjp2a.15I
# tjp2a.15J
# tjp2a.15K
# tjp2a.15L
# tjp2a.15M
# tjp2a.15N
# tjp2a.15O
# tjp2a.15P
# tjp2a.17wt
# tjp2a.17B
# tjp2a.17C
# tjp2a.18I
# tjp2a.18J
# tjp2a.18K
# tjp2a.18L
# tjp2a.18M
# tjp2a.18wt
# tjp2a.18B
# tjp2a.18C
# tjp2a.18D
# tjp2a.18E
# tjp2a.18F
# tjp2a.18G
# tjp2a.18H
# tjp2b.15wt
# tjp2b.15B
# tjp2b.15C
# tjp2b.15D
# tjp2b.15E
# tjp2b.15F
# tjp2b.15G
# tjp2b.15H
# tjp2b.15I
# tjp2b.15J
# tjp2b.15K
# tjp2b.15L
# tjp2b.15M
# tjp2b.15N
# tjp2b.15O
# tjp2b.15P
# tjp2b.17wt
# tjp2b.17B
# tjp2b.17C
# tjp2b.18I
# tjp2b.18J
# tjp2b.18K
# tjp2b.18L
# tjp2b.18M
# tjp2b.18wt
# tjp2b.18B
# tjp2b.18C
# tjp2b.18D
# tjp2b.18E
# tjp2b.18F
# tjp2b.18G
# tjp2b.18H
# nrxn3aL.17wt
# nrxn3aL.17B
# nrxn3aL.17C
# nrxn3aL.17D
# nrxn3aL.17E
# nrxn3aL.17F
# nrxn3aL.17G
# nrxn3aL.17H
# nrxn3aL.17I
# nrxn3aL.17J
# nrxn3aL.17K
# nrxn3aL.17L
# nrxn3aL.17M
# nrxn3aL.17N
# nrxn3aL.17O
# nrxn3aL.17P
# nrxn3bS.17wt
# nrxn3bS.17B
# nrxn3bS.17C
# nrxn3bS.17D
# nrxn3bS.17E
# nrxn3bS.17F
# nrxn3bS.17G
# nrxn3bS.17H
# nrxn3bS.17I
# nrxn3bS.17J
# nrxn3bS.17K
# nrxn3bS.17L
# nrxn3bS.17M
# nrxn3bS.17N
# nrxn3bS.17O
# nrxn3bS.17P

# %%
d1i = {'gene': 'tjp2a', 'idnumbers': [6,7,8,9,11,12], 'letters': ['wti','Bi','Ci','Di','Ei','Fi','Gi','Hi']}
d1ii = {'gene': 'tjp2a', 'idnumbers': [6,7,8,9,11,12], 'letters': ['wtii','Bii','Cii','Dii','Eii','Fii','Gii','Hii']}
# d2 = {'gene': 'tjp2b', 'idnumbers': [8,11,12], 'letters': ['wt','B','C','D','E','F','G','H']}
# d3 = {'gene': 'cadm1a', 'idnumbers': [10,11,12], 'letters': ['wt','B','C','D','E','F','G','H']}
# d4 = {'gene': 'cpne3', 'idnumbers': [11], 'letters': ['wt','B','C','D','E','F','G','H']}
# d5 = {'gene': 'tjp2a_bis', 'idnumbers': [8,11], 'letters': ['wt','B','C','D','E','F','G','H']}
# metad = [d1,d2,d3,d4,d5]
metad = [d1i,d1ii]
printNames(metad)
# Out:
# tjp2a.6_wti
# tjp2a.6_Bi
# tjp2a.6_Ci
# tjp2a.6_Di
# tjp2a.6_Ei
# tjp2a.6_Fi
# tjp2a.6_Gi
# tjp2a.6_Hi
# tjp2a.7_wti
# tjp2a.7_Bi
# tjp2a.7_Ci
# tjp2a.7_Di
# tjp2a.7_Ei
# tjp2a.7_Fi
# tjp2a.7_Gi
# tjp2a.7_Hi
# tjp2a.8_wti
# tjp2a.8_Bi
# tjp2a.8_Ci
# tjp2a.8_Di
# tjp2a.8_Ei
# tjp2a.8_Fi
# tjp2a.8_Gi
# tjp2a.8_Hi
# tjp2a.9_wti
# tjp2a.9_Bi
# tjp2a.9_Ci
# tjp2a.9_Di
# tjp2a.9_Ei
# tjp2a.9_Fi
# tjp2a.9_Gi
# tjp2a.9_Hi
# tjp2a.11_wti
# tjp2a.11_Bi
# tjp2a.11_Ci
# tjp2a.11_Di
# tjp2a.11_Ei
# tjp2a.11_Fi
# tjp2a.11_Gi
# tjp2a.11_Hi
# tjp2a.12_wti
# tjp2a.12_Bi
# tjp2a.12_Ci
# tjp2a.12_Di
# tjp2a.12_Ei
# tjp2a.12_Fi
# tjp2a.12_Gi
# tjp2a.12_Hi
# tjp2a.6_wtii
# tjp2a.6_Bii
# tjp2a.6_Cii
# tjp2a.6_Dii
# tjp2a.6_Eii
# tjp2a.6_Fii
# tjp2a.6_Gii
# tjp2a.6_Hii
# tjp2a.7_wtii
# tjp2a.7_Bii
# tjp2a.7_Cii
# tjp2a.7_Dii
# tjp2a.7_Eii
# tjp2a.7_Fii
# tjp2a.7_Gii
# tjp2a.7_Hii
# tjp2a.8_wtii
# tjp2a.8_Bii
# tjp2a.8_Cii
# tjp2a.8_Dii
# tjp2a.8_Eii
# tjp2a.8_Fii
# tjp2a.8_Gii
# tjp2a.8_Hii
# tjp2a.9_wtii
# tjp2a.9_Bii
# tjp2a.9_Cii
# tjp2a.9_Dii
# tjp2a.9_Eii
# tjp2a.9_Fii
# tjp2a.9_Gii
# tjp2a.9_Hii
# tjp2a.11_wtii
# tjp2a.11_Bii
# tjp2a.11_Cii
# tjp2a.11_Dii
# tjp2a.11_Eii
# tjp2a.11_Fii
# tjp2a.11_Gii
# tjp2a.11_Hii
# tjp2a.12_wtii
# tjp2a.12_Bii
# tjp2a.12_Cii
# tjp2a.12_Dii
# tjp2a.12_Eii
# tjp2a.12_Fii
# tjp2a.12_Gii
# tjp2a.12_Hii
