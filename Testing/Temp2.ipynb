# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# Crypto              boto                jupyter             sched
# Cython              bottleneck          jupyter_client      scipy
# IN                  bs4                 jupyter_console     seaborn
# IPython             builtins            jupyter_core        select
# OpenSSL             bz2                 jupyterthemes       selectors
# PIL                 cProfile            keyword             setuptools
# PyQt4               calendar            lib2to3             shelve
# __future__          cffi                linecache           shlex
# _ast                cgi                 llvmlite            shutil
# _bisect             cgitb               locale              signal
# _bootlocale         chest               locket              simplegeneric
# _bz2                chunk               logging             singledispatch
# ...
