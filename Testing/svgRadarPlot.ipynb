# %% [markdown]
# ---
# ## SVG Radar plot
# ---
# >Almost generalized radar plot
# >Intended to visualize zf_hC and zf_bC specificity for photoreceptor subtypes.
# ---
#
# This script:
# 1. Creates all the axis
# 1. Creates relevant polygons (every 5 units)
# 1. Creates colored dots for each data point
# 1. Creates cell contour
# 1. Creates a side plot for the unassigned data

# %%
import hcPlot
import pandas
import importlib
import svgwrite
import math

def svgreload():
    # !osascript -e 'tell application "Google Chrome" to tell the active tab of second window to reload'

# %%
# hcDF=pandas.read_csv("/Users/angueyra/Dropbox/LiLab/hCAnalysis/201808_hcQuant_Nia.csv")
hcDF=pandas.read_csv("~/Dropbox/LiLab/hCAnalysis/201808_hcQuant_Nia.csv")
hcData=hcDF[['uv','s','m','l','r','z']].values

# %%
hcDF
# Out:
#                                              filename type         label  uv  \
# 0                      20180309_zfA_DiI_PNA488_01_63x   H3        PNA488  12
# 1                         20180329_zfA_sws1GFP_DiI_01   H2           s1G   4
# 2                         20180329_zfA_sws1GFP_DiI_02   H2           s1G   5
# 3                         20180329_zfA_sws1GFP_DiI_03   H3           s1G  15
# 4                         20180329_zfA_sws1GFP_DiI_04   H3           s1G  19
# 5                 20180424_sws1GFP_DiI_PNA647_01a_63x   H3    s1G\PNA647  15
# 6                 20180424_sws1GFP_DiI_PNA647_01b_63x   H2    s1G\PNA647   5
# 7                        20180424_sws2GFP_DiI_01a_63x   H3           s2G  15
# 8                20180709_zfA_GE4G_DiI_PNA647_01b_63x   H1        PNA647   3
# 9                20180709_zfA_GE4G_DiI_PNA647_02a_63x   H1        PNA647   1
# 10               20180709_zfA_GE4G_DiI_PNA647_02b_63x   H1        PNA647   0
# 11          20180725_zfA_aCtdT_DiO_PNA647_01a_63x_hCs   H1  actdT\PNA647   4
# 12          20180725_zfA_aCtdT_DiO_PNA647_01b_63x_hCs   H1  actdT\PNA647   0
# 13  20180725_zfA_aCtdT_DiO_PNA647_02a_63x_hCs_dend...   H3  actdT\PNA647  11
# 14  20180725_zfA_aCtdT_DiO_PNA647_02b_63x_hCs_dend...   H3  actdT\PNA647  15
# 15          20180725_zfA_aCtdT_DiO_PNA647_03a_63x_hCs   H3  actdT\PNA647  16
# 16          20180725_zfA_aCtdT_DiO_PNA647_03b_63x_hCs   H1  actdT\PNA647   1
# 17          20180725_zfA_aCtdT_DiO_PNA647_04a_63x_hCs   H2  actdT\PNA647   4
# 18            20180725_zfA_s1G_DiI_PNA647_05a_63x_hCs   H1    s1G\PNA647   0
# 19            20180725_zfA_s1G_DiI_PNA647_05b_63x_hCs   H1    s1G\PNA647   0
# 20            20180725_zfA_s1G_DiI_PNA647_05c_63x_hCs   H1    s1G\PNA647   0
# 21            20180725_zfA_s1G_DiI_PNA647_06a_63x_hCs   H3    s1G\PNA647  13
# 22            20180725_zfA_s1G_DiI_PNA647_07a_63x_hCs   H1    s1G\PNA647   0
# 23            20180725_zfA_s1G_DiI_PNA647_07b_63x_hCs   H1    s1G\PNA647   0
# 24            20180725_zfA_s1G_DiI_PNA647_08a_63x_hCs   H3    s1G\PNA647  15
# 25           20180726_zfA_aCtdT_DiO_PNA647_10a_63x_hC  NaN           NaN   0
# 26           20180726_zfA_aCtdT_DiO_PNA647_11a_63x_hC   H2  actdT\PNA647   3
# 27           20180726_zfA_aCtdT_DiO_PNA647_12a_63x_hC   H2  actdT\PNA647   5
# 28           20180726_zfA_aCtdT_DiO_PNA647_13a_63x_hC   H1  actdT\PNA647   0
# 29           20180726_zfA_aCtdT_DiO_PNA647_14a_63x_hC   H3  actdT\PNA647  13
# 30           20180726_zfA_aCtdT_DiO_PNA647_14b_63x_hC   H1  actdT\PNA647   0
# 31           20180726_zfA_aCtdT_DiO_PNA647_15a_63x_hC   H1  actdT\PNA647   0
# 32           20180726_zfA_aCtdT_DiO_PNA647_16a_63x_hC   H1  actdT\PNA647   0
# 33      20180726_zfA_aCtdT_DiO_PNA647_17a_63x_wierdhC   H2  actdT\PNA647   5
#
#      s   m   l  r  z
# 0    7   0   0  0  1
# 1    4  11   2  0  0
# 2    6  12   0  0  0
# 3   11   0   0  0  0
# 4   11   0   0  0  0
# 5   13   0   0  0  0
# 6    5  10   0  0  0
# 7   13   0   0  0  1
# 8    1   8   3  0  4
# 9    1   7   6  0  1
# 10   2   7   5  0  0
# 11   4   9  10  0  1
# 12   2   7   9  0  0
# 13   7   0   1  0  1
# 14   8   0   0  0  0
# 15   9   0   0  0  0
# 16   2   8   6  0  0
# 17   5   7   0  0  0
# 18   2   8  11  0  2
# 19   2   6  12  0  0
# 20   2   9  10  0  1
# 21  12   0   0  0  2
# 22   2   9   6  0  0
# 23   1   8  10  0  3
# 24  12   0   0  0  0
# 25   0   0   0  0  0
# 26   5   8   3  0  0
# 27   7   8   2  0  0
# 28   2   7   8  0  0
# 29  11   1   1  0  0
# 30   0   3   5  0  0
# 31   3   7   8  0  0
# 32   1   6  10  0  0
# 33   3   6   0  0  0

# %% [markdown]
# ### Plot a single cell

# %%
importlib.reload(hcPlot)
dwg = hcPlot.hcCanvas('test-svgwrite');
realCell = hcPlot.plotCell(dwg,hcData[2])
dwg.canvas.save()
# print(dwg.canvas.tostring())
svgreload()

# %% [markdown]
# ### Make and save plots all cells

# %%
importlib.reload(hcPlot)
for i in range(hcData.shape[0]):
    svgfilename='./hcPlots/hc' + str(i).zfill(2)
    dwg = hcPlot.hcCanvas(svgfilename);
    realCell = hcPlot.plotCell(dwg,hcData[i])
    dwg.canvas.save()

# %% [markdown]
# ### Make a compound svg with all of them

# %%
from svgutils.compose import *

nx=6
ny=math.ceil(34/nx)

sizeX = str(nx * 325)
sizeY = str(ny * 250)

Figure(sizeX, sizeY,
       SVG("./hcPlots/hc00.svg").scale(0.5),
       SVG("./hcPlots/hc01.svg").scale(0.5),
       SVG("./hcPlots/hc02.svg").scale(0.5),
       
       SVG("./hcPlots/hc03.svg").scale(0.5),
       SVG("./hcPlots/hc04.svg").scale(0.5),
       SVG("./hcPlots/hc05.svg").scale(0.5),
       
       SVG("./hcPlots/hc06.svg").scale(0.5),
       SVG("./hcPlots/hc07.svg").scale(0.5),
       SVG("./hcPlots/hc08.svg").scale(0.5),
       
       SVG("./hcPlots/hc09.svg").scale(0.5),
       SVG("./hcPlots/hc10.svg").scale(0.5),
       SVG("./hcPlots/hc11.svg").scale(0.5),
       
       SVG("./hcPlots/hc12.svg").scale(0.5),
       SVG("./hcPlots/hc13.svg").scale(0.5),
       SVG("./hcPlots/hc14.svg").scale(0.5),
       
       SVG("./hcPlots/hc15.svg").scale(0.5),
       SVG("./hcPlots/hc16.svg").scale(0.5),
       SVG("./hcPlots/hc17.svg").scale(0.5),
       
       SVG("./hcPlots/hc18.svg").scale(0.5),
       SVG("./hcPlots/hc19.svg").scale(0.5),
       SVG("./hcPlots/hc20.svg").scale(0.5),
              
       SVG("./hcPlots/hc21.svg").scale(0.5),
       SVG("./hcPlots/hc22.svg").scale(0.5),
       SVG("./hcPlots/hc23.svg").scale(0.5),
              
       SVG("./hcPlots/hc24.svg").scale(0.5),
       SVG("./hcPlots/hc25.svg").scale(0.5),
       SVG("./hcPlots/hc26.svg").scale(0.5),
                     
       SVG("./hcPlots/hc27.svg").scale(0.5),
       SVG("./hcPlots/hc28.svg").scale(0.5),
       SVG("./hcPlots/hc29.svg").scale(0.5),
                     
       SVG("./hcPlots/hc30.svg").scale(0.5),
       SVG("./hcPlots/hc31.svg").scale(0.5),
       SVG("./hcPlots/hc32.svg").scale(0.5),
                            
       SVG("./hcPlots/hc33.svg").scale(0.5),

       ).tile(nx, ny).save("test-svgwrite.svg")
svgreload()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-90d33116cdb1> in <module>()
#       8
#       9 Figure(sizeX, sizeY,
# ---> 10        SVG("./hcPlots/hc00.svg").scale(0.5).opacity(0.5),
#      11        SVG("./hcPlots/hc01.svg").scale(0.5),
#      12        SVG("./hcPlots/hc02.svg").scale(0.5),
#
# AttributeError: 'SVG' object has no attribute 'opacity'

# %% [markdown]
# #### Things to do
# 1. Make an svg for each cell - DONE!
# 1. Make wrapper to make gallery - DONE! (using svgutils)
# 1. Allow wrapper to change opacity of individual panels and change color accordingly to type
#     1. think I need to put an id handle in individual svgs to do this
#     1. try to put id according to cell type (H1, H2, H3 or Other)
