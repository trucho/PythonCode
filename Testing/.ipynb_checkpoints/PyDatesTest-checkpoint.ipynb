# %%
import calendar
st_week=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday' 'Sunday']
st_months=['January','February','March','April','May','June','July','August','September','October','November','December']
def dprint(dnumber):
    if dnumber==1:
        ith = 'st'
    elif dnumber==2:
        ith = 'nd'
    elif dnumber==3:
        ith = 'rd'
    else:
        ith='th'
    d='{:02g}'.format(dnumber) + ith
    return d

monthi=7
month=st_months[monthi-1]
calmonth=calendar.monthcalendar(2016,monthi)
print ('-' + month)
for i in range(len(calmonth)):
    print ('\t- '+ month + ' ' + dprint(calmonth[i][0]) + ' - ' + dprint(calmonth[i][6]))
    for d in range(len(st_week)):
        print ('\t\t- ' + st_week[d] + ' ' + dprint(calmonth[i][d]))
# Out:
# -July
# 	- July 00th - 03rd
# 		- Monday 00th
# 		- Tuesday 00th
# 		- Wednesday 00th
# 		- Thursday 00th
# 		- Friday 01st
# 		- SaturdaySunday 02nd
# 	- July 04th - 10th
# 		- Monday 04th
# 		- Tuesday 05th
# 		- Wednesday 06th
# 		- Thursday 07th
# 		- Friday 08th
# 		- SaturdaySunday 09th
# 	- July 11th - 17th
# 		- Monday 11th
# 		- Tuesday 12th
# 		- Wednesday 13th
# 		- Thursday 14th
# 		- Friday 15th
# 		- SaturdaySunday 16th
# 	- July 18th - 24th
# 		- Monday 18th
# 		- Tuesday 19th
# 		- Wednesday 20th
# 		- Thursday 21th
# 		- Friday 22th
# 		- SaturdaySunday 23th
# 	- July 25th - 31th
# 		- Monday 25th
# 		- Tuesday 26th
# 		- Wednesday 27th
# 		- Thursday 28th
# 		- Friday 29th
# 		- SaturdaySunday 30th
