# %%
# Tile

# %%
# !conda install -c anaconda-nb-extensions nb_anacondacloud=1.1.0 --y
# Out:
# Using Anaconda Cloud api site https://api.anaconda.org
# Fetching package metadata .........
# Solving package specifications: ..........
#
# Package plan for installation in environment /Users/angueyraaristjm/anaconda:
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     nb_anacondacloud-1.1.0     |           py35_1          21 KB  anaconda-nb-extensions
#
# The following packages will be UPDATED:
#
#     nb_anacondacloud: 1.1.0-py35_0 --> 1.1.0-py35_1 anaconda-nb-extensions
#
# Fetching packages ...
# nb_anacondaclo 100% |################################| Time: 0:00:00   3.10 MB/s
# Extracting packages ...
# [      COMPLETE      ]|###################################################| 100%
# Unlinking packages ...
# [      COMPLETE      ]|###################################################| 100%
# Linking packages ...
# ...

# %%
## sub title

# %%
# !conda update conda -y
# Out:
# Using Anaconda Cloud api site https://api.anaconda.org
# Fetching package metadata: ....
# .Solving package specifications: .........
#
# Package plan for installation in environment /Users/angueyraaristjm/anaconda:
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     sqlite-3.13.0              |                0         1.4 MB
#     xz-5.2.2                   |                0         186 KB
#     libtiff-4.0.6              |                2         738 KB
#     python-3.5.2               |                0        12.6 MB
#     anaconda-custom            |           py35_0           3 KB
#     conda-env-2.5.1            |           py35_0          27 KB
#     ruamel_yaml-0.11.14        |           py35_0         178 KB
#     conda-4.1.11               |           py35_0         204 KB
#     ------------------------------------------------------------
# ...

# %%
# !conda update anaconda --y
# Out:
# Fetching package metadata .......
# Solving package specifications: ..........
#
# Package plan for installation in environment /Users/angueyraaristjm/anaconda:
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mkl-11.3.3                 |                0       101.4 MB
#     openssl-1.0.2h             |                1         3.0 MB
#     redis-3.2.0                |                0         947 KB
#     zlib-1.2.8                 |                3          89 KB
#     curl-7.49.0                |                0         494 KB
#     hdf5-1.8.16                |                0         1.7 MB
#     libpng-1.6.22              |                0         225 KB
#     alabaster-0.7.8            |           py35_0          18 KB
#     backports-1.0              |           py35_0           1 KB
#     boto-2.40.0                |           py35_0         1.4 MB
# ...
